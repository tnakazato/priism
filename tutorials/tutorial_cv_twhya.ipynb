# %% [markdown]
# # TW Hya Imaging Tutorial

# %% [markdown]
# This notebook is a tutorial of synthesis imaging based on the sparse modeling technique using PRIISM.
# **PRIISM** is an imaging tool for radio interferometry based on the sparse modeling technique ([PRIISM](https://github.com/tnakazato/priism): Python Module for Radio Interferometry Imaging with Sparse Modeling).
#
# In this tutorial, we try synthesis imaging for ALMA interferometry data using interactive PRIISM API for ALMA, `priism.alma`. For batch processing using `priism.runner`, please see `tutorial_hltau.ipynb`.

# %% [markdown]
# ## Setup and Initialize PRIISM

# %% [markdown]
# Before you start this tutorial, you should install PRIISM and packages that PRIISM depends on (casatools, casatasks, etc.). Please see README.md on how to install PRIISM. In addition, you need to install `astropy` because this tutorial uses `astropy` to display final image.
#
# There are two fundamental submodules for imaging, `priism.core` and `priism.alma`, which are mainly for interactive use. For batch mode, we have `priism.runner` submodule. This tutorial is using interactive API provided by `priism.alma`. First of all, we create worker instance for interactive imaging.

# %%
import priism.alma
print(f'PRIISM version {priism.__version__}')

worker = priism.alma.AlmaSparseModelingImager(solver='pymfista_nufft')
# Out:
# PRIISM version 0.16.2

# %% [markdown]
# We make matplotlib figures to be displayed in the notebook.

# %%
# %matplotlib inline

# %% [markdown]
# ## ALMA Data : TW Hya

# %% [markdown]
# Sample data for the tutorial is the protoplanetary disk "**TW Hydra**" observed at Band 7 with ALMA 12m array (Project 2011.0.00340.S).
# The data infromation is taken in [First Look at Imaging CASA 6](https://casaguides.nrao.edu/index.php?title=First_Look_at_Imaging), and the data, which is a calibrated measurement set (MS) for CASA, can be downloaded from the link below:
#
# https://bulk.cv.nrao.edu/almadata/public/casaguides/FirstLook_TWHya_Band7_6.6.1/twhya_calibrated.ms.tar
#
# After you download the data, you should extract the MS from the file. You may run the following cell to obtain the dataset.

# %%
# %%bash
# # download if necessary
# [ -e twhya_calibrated.ms.tar ] || wget -nv https://bulk.cv.nrao.edu/almadata/public/casaguides/FirstLook_TWHya_Band7_6.6.1/twhya_calibrated.ms.tar
#
# # extract MS if it doesn't exist
# [ -e twhya_calibrated.ms ] || tar xvf twhya_calibrated.ms.tar
# Out:
# 2026-08-28 07:16:13 URL:https://bulk.cv.nrao.edu/almadata/public/casaguides/FirstLook_TWHya_Band7_6.6.1/twhya_calibrated.ms.tar [435742720/435742720] -> "twhya_calibrated.ms.tar" [1]
# twhya_calibrated.ms/
# twhya_calibrated.ms/FEED/
# twhya_calibrated.ms/FEED/table.dat
# twhya_calibrated.ms/FEED/table.lock
# twhya_calibrated.ms/FEED/table.f0
# twhya_calibrated.ms/FEED/table.info
# twhya_calibrated.ms/FEED/table.f0i
# twhya_calibrated.ms/table.f4
# twhya_calibrated.ms/SYSCAL/
# twhya_calibrated.ms/SYSCAL/table.info
# twhya_calibrated.ms/SYSCAL/table.f0i
# twhya_calibrated.ms/SYSCAL/table.lock
# twhya_calibrated.ms/SYSCAL/table.f0
# twhya_calibrated.ms/SYSCAL/table.dat
# twhya_calibrated.ms/ASDM_ANTENNA/
# twhya_calibrated.ms/ASDM_ANTENNA/table.info
# twhya_calibrated.ms/ASDM_ANTENNA/table.f0i
# twhya_calibrated.ms/ASDM_ANTENNA/table.dat
# twhya_calibrated.ms/ASDM_ANTENNA/table.lock
# twhya_calibrated.ms/ASDM_ANTENNA/table.f0
# twhya_calibrated.ms/FLAG_CMD/
# twhya_calibrated.ms/FLAG_CMD/table.f0
# twhya_calibrated.ms/FLAG_CMD/table.info
# twhya_calibrated.ms/FLAG_CMD/table.dat
# twhya_calibrated.ms/FLAG_CMD/table.lock
# twhya_calibrated.ms/table.f20_TSM1
# twhya_calibrated.ms/table.f14
# twhya_calibrated.ms/ASDM_STATION/
# twhya_calibrated.ms/ASDM_STATION/table.lock
# twhya_calibrated.ms/ASDM_STATION/table.f0
# twhya_calibrated.ms/ASDM_STATION/table.f0i
# twhya_calibrated.ms/ASDM_STATION/table.info
# twhya_calibrated.ms/ASDM_STATION/table.dat
# twhya_calibrated.ms/table.f13
# twhya_calibrated.ms/table.f19
# twhya_calibrated.ms/table.f21
# twhya_calibrated.ms/ASDM_CALWVR/
# twhya_calibrated.ms/ASDM_CALWVR/table.dat
# twhya_calibrated.ms/ASDM_CALWVR/table.lock
# twhya_calibrated.ms/ASDM_CALWVR/table.info
# twhya_calibrated.ms/ASDM_CALWVR/table.f0
# twhya_calibrated.ms/ASDM_CALWVR/table.f0i
# twhya_calibrated.ms/table.f9
# twhya_calibrated.ms/table.f3
# twhya_calibrated.ms/table.f7
# twhya_calibrated.ms/ASDM_RECEIVER/
# twhya_calibrated.ms/ASDM_RECEIVER/table.lock
# twhya_calibrated.ms/ASDM_RECEIVER/table.dat
# twhya_calibrated.ms/ASDM_RECEIVER/table.f0
# twhya_calibrated.ms/ASDM_RECEIVER/table.info
# twhya_calibrated.ms/ASDM_RECEIVER/table.f0i
# twhya_calibrated.ms/FIELD/
# twhya_calibrated.ms/FIELD/table.info
# twhya_calibrated.ms/FIELD/table.dat
# twhya_calibrated.ms/FIELD/table.lock
# twhya_calibrated.ms/FIELD/table.f0i
# twhya_calibrated.ms/FIELD/table.f0
# twhya_calibrated.ms/table.f17
# twhya_calibrated.ms/SPECTRAL_WINDOW/
# twhya_calibrated.ms/SPECTRAL_WINDOW/table.lock
# twhya_calibrated.ms/SPECTRAL_WINDOW/table.f0i
# twhya_calibrated.ms/SPECTRAL_WINDOW/table.info
# twhya_calibrated.ms/SPECTRAL_WINDOW/table.f0
# twhya_calibrated.ms/SPECTRAL_WINDOW/table.dat
# twhya_calibrated.ms/POLARIZATION/
# twhya_calibrated.ms/POLARIZATION/table.lock
# twhya_calibrated.ms/POLARIZATION/table.dat
# twhya_calibrated.ms/POLARIZATION/table.f0i
# twhya_calibrated.ms/POLARIZATION/table.f0
# twhya_calibrated.ms/POLARIZATION/table.info
# twhya_calibrated.ms/table.f10
# twhya_calibrated.ms/table.lock
# twhya_calibrated.ms/table.f22
# twhya_calibrated.ms/OBSERVATION/
# twhya_calibrated.ms/OBSERVATION/table.lock
# twhya_calibrated.ms/OBSERVATION/table.dat
# twhya_calibrated.ms/OBSERVATION/table.info
# twhya_calibrated.ms/OBSERVATION/table.f0
# twhya_calibrated.ms/table.f21_TSM1
# twhya_calibrated.ms/HISTORY/
# twhya_calibrated.ms/HISTORY/table.f0
# twhya_calibrated.ms/HISTORY/table.lock
# twhya_calibrated.ms/HISTORY/table.dat
# twhya_calibrated.ms/HISTORY/table.info
# twhya_calibrated.ms/ANTENNA/
# twhya_calibrated.ms/ANTENNA/table.info
# twhya_calibrated.ms/ANTENNA/table.dat
# twhya_calibrated.ms/ANTENNA/table.lock
# twhya_calibrated.ms/ANTENNA/table.f0
# twhya_calibrated.ms/table.f19_TSM0
# twhya_calibrated.ms/table.f2
# twhya_calibrated.ms/table.f8
# twhya_calibrated.ms/table.f18
# twhya_calibrated.ms/DATA_DESCRIPTION/
# twhya_calibrated.ms/DATA_DESCRIPTION/table.f0
# twhya_calibrated.ms/DATA_DESCRIPTION/table.info
# twhya_calibrated.ms/DATA_DESCRIPTION/table.dat
# twhya_calibrated.ms/DATA_DESCRIPTION/table.lock
# twhya_calibrated.ms/table.f12
# twhya_calibrated.ms/table.f20
# twhya_calibrated.ms/table.dat
# twhya_calibrated.ms/SOURCE/
# twhya_calibrated.ms/SOURCE/table.info
# twhya_calibrated.ms/SOURCE/table.f0
# twhya_calibrated.ms/SOURCE/table.f0i
# twhya_calibrated.ms/SOURCE/table.dat
# twhya_calibrated.ms/SOURCE/table.lock
# twhya_calibrated.ms/CALDEVICE/
# twhya_calibrated.ms/CALDEVICE/table.f0i
# twhya_calibrated.ms/CALDEVICE/table.lock
# twhya_calibrated.ms/CALDEVICE/table.f0
# twhya_calibrated.ms/CALDEVICE/table.info
# twhya_calibrated.ms/CALDEVICE/table.dat
# twhya_calibrated.ms/SYSPOWER/
# twhya_calibrated.ms/SYSPOWER/table.lock
# twhya_calibrated.ms/SYSPOWER/table.f0i
# twhya_calibrated.ms/SYSPOWER/table.f0
# twhya_calibrated.ms/SYSPOWER/table.dat
# twhya_calibrated.ms/SYSPOWER/table.info
# twhya_calibrated.ms/table.f15
# twhya_calibrated.ms/table.f5
# twhya_calibrated.ms/PROCESSOR/
# twhya_calibrated.ms/PROCESSOR/table.lock
# twhya_calibrated.ms/PROCESSOR/table.dat
# twhya_calibrated.ms/PROCESSOR/table.info
# twhya_calibrated.ms/PROCESSOR/table.f0
# twhya_calibrated.ms/WEATHER/
# twhya_calibrated.ms/WEATHER/table.f0
# twhya_calibrated.ms/WEATHER/table.info
# twhya_calibrated.ms/WEATHER/table.dat
# twhya_calibrated.ms/WEATHER/table.lock
# twhya_calibrated.ms/table.f1
# twhya_calibrated.ms/table.f17_TSM1
# twhya_calibrated.ms/table.info
# twhya_calibrated.ms/table.f11
# twhya_calibrated.ms/table.f22_TSM1
# twhya_calibrated.ms/table.f16
# twhya_calibrated.ms/STATE/
# twhya_calibrated.ms/STATE/table.lock
# twhya_calibrated.ms/STATE/table.dat
# twhya_calibrated.ms/STATE/table.f0
# twhya_calibrated.ms/STATE/table.info
# twhya_calibrated.ms/table.f6
# twhya_calibrated.ms/POINTING/
# twhya_calibrated.ms/POINTING/table.f0
# twhya_calibrated.ms/POINTING/table.dat
# twhya_calibrated.ms/POINTING/table.lock
# twhya_calibrated.ms/POINTING/table.info
# twhya_calibrated.ms/POINTING/table.f0i

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Next, we average visibility channels according to the procedure described in [the CASA Guide](https://casaguides.nrao.edu/index.php?title=First_Look_at_Imaging_CASA_6#Image_the_science_target). This requires `casatasks` that should have been installed as a dependency of PRIISM. We use `twhya_smoothed.ms` in the subsequent steps.

# %%
import os
import shutil
from casatasks import listobs, split, rmtables

outputvis = 'twhya_smoothed.ms'
listfile = 'twhya_smoothed.listobs.txt'

# overwrite output data if it exists
rmtables(outputvis)

split(vis='twhya_calibrated.ms', field='5', width='8', outputvis=outputvis, datacolumn='data')

data_summary = listobs(outputvis, verbose=True, overwrite=True, listfile=listfile)

# extract spw setup from data summary
os.system(f'grep -E "^Spectral Windows:" -A 2 {listfile}')
# Out:
# Spectral Windows:  (1 unique spectral windows and 1 unique polarization setups)
#   SpwID  Name                           #Chans   Frame   Ch0(MHz)  ChanWid(kHz)  TotBW(kHz) CtrFreq(MHz) BBC Num  Corrs
#   0      ALMA_RB_07#BB_2#SW-01#FULL_RES     48   TOPO  372535.223      4882.812    234375.0 372649.9688        2  XX  YY
# 0

# %% [markdown]
# ## Data Selection

# %% [markdown]
# Next step is to select visibility data to be processed. The `worker` has `selectdata` method for this purpose. Its interface might be familiar with CASA users. You should set MS to `vis`. Also, you should specify name of data column to use with `datacolumn`. `selectdata` accepts major data selection parameters in CASA. Here, we select data with `spw` and `intent`.

# %%
worker.selectdata(vis='twhya_smoothed.ms',
                  spw='0:24',
                  intent='OBSERVE_TARGET#ON_SOURCE',
                  datacolumn='data')

# %% [markdown]
# ## Image Configuration

# %% [markdown]
# Then, image to be created should be configured with `defineimage` function. Again, parameters for it might be familiar with CASA users. Note that `phasecenter` currently accepts field id only. Also, `nchan` should be 1. These limitation may be relaxed in the future.

# %%
worker.defineimage(imsize=[256, 256],
                   cell=['0.08arcsec'],
                   phasecenter='0',  # TW Hya
                   nchan=1,
                   start=0,
                   width=1)

# %% [markdown]
# ## Read Visibility Data

# %% [markdown]
# Configuration has been done. And actual processing starts from here. First processing step is to read MS and load visibility data onto the memory.

# %%
# %%timeit -n 1 -r 1

worker.readvis()
# Out:
# 2026/08/28 07:16:17	WARNING	_warn_refocus	***WARN*** refocusing is disabled even if distance to the source is known.
# read 200 visibility chunks
# 2026/08/28 07:16:21	INFO	readvis	read 270 visibility chunks
# 2026/08/28 07:16:21	INFO	readvis	DONE reading visibility chunks
# 3.41 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# read 270 visibility chunks

# %% [markdown]
# ## Direct Imaging

# %% [markdown]
# Now you can create an image from the visibility data. There are two parameters for imaging: `L1` and `Ltsv`. They are hyper parameters for regularization terms. Once you give these parameters, you will obtain one image. For imaging, you should run `solve` to solve the problem and then run `exportimage` to export the solution as FITS image. Please note that intensity unit of resulting image will be **Jy/pixel** if input visibility data is correctly calibrated.
#
# This step may take up to a minute.

# %%
# %%timeit -n 1 -r 1

worker.solve(l1=1e0, ltsv=1e8, maxiter=1000, storeinitialimage=True, scalehyperparam=False)
worker.exportimage(imagename='twhya_b7cont.fits', overwrite=True)
# Out:
# 2026/08/28 07:16:38	INFO	mfista_L1_TSV_core_nufft	converged at iter 334
# 2026/08/28 07:16:38	INFO	_show_result
# 2026/08/28 07:16:38	INFO	_show_result
# 2026/08/28 07:16:38	INFO	_show_result	Size of the problem:
# 2026/08/28 07:16:38	INFO	_show_result	 size of input vector:  44772
# 2026/08/28 07:16:38	INFO	_show_result	 size of output vector: 65536
# 2026/08/28 07:16:38	INFO	_show_result	size of image:          256 x 256
# 2026/08/28 07:16:38	INFO	_show_result
# 2026/08/28 07:16:38	INFO	_show_result	Problem Setting:
# 2026/08/28 07:16:38	INFO	_show_result	 x is a nonnegative vector.
#
# 2026/08/28 07:16:38	INFO	_show_result	 Lambda_l1: 1.000000e+00
# 2026/08/28 07:16:38	INFO	_show_result	 Lambda_tsv: 1.000000e+08
# 2026/08/28 07:16:38	INFO	_show_result	 MAXITER: 1000
# 2026/08/28 07:16:38	INFO	_show_result
# 2026/08/28 07:16:38	INFO	_show_result	Results:
# 2026/08/28 07:16:38	INFO	_show_result	 # of iterations:       335
# 2026/08/28 07:16:38	INFO	_show_result	 cost:                  3.133743e+02
# 2026/08/28 07:16:38	INFO	_show_result	 computation time[sec]: 0.000000e+00
#
# 2026/08/28 07:16:38	INFO	_show_result	 # of nonzero pixels:   40941
# 2026/08/28 07:16:38	INFO	_show_result	 Squared Error (SE):    6.265995e+02
# 2026/08/28 07:16:38	INFO	_show_result	 Mean SE:               1.399534e-02
# 2026/08/28 07:16:38	INFO	_show_result	 L1 cost:               3.715601e-02
# 2026/08/28 07:16:38	INFO	_show_result	 TSV cost:              3.733102e-10
# 2026/08/28 07:16:38	INFO	exportimage	spw_chan_list: [[ 0 24 24  1]]
# 2026/08/28 07:16:38	INFO	_setup_coordsys	Output image summary:
# Direction reference : J2000
# Spectral  reference : LSRK
# Velocity  type      : RADIO
# Rest frequency      : 1.42041e+09 Hz
# Telescope           : ALMA
# Observer            : cqi
# Date observation    : 2012/11/19/07:27:43.941999
# Telescope position: [2.22514e+06m, -5.44031e+06m, -2.48103e+06m] (ITRF)
#
# Axis Coord Type      Name             Proj   Coord value at pixel      Coord incr Units
# ---------------------------------------------------------------------------------------
# 0    0     Direction Right Ascension   SIN  11:01:51.796   128.00   -8.000000e-02 arcsec
# 1    0     Direction Declination       SIN -34.42.17.366   128.00    8.000000e-02 arcsec
# 2    1     Stokes    Stokes                            I
# 3    2     Spectral  Frequency               3.72639e+11     0.00 4.882641272e+06 Hz
#                      Velocity               -7.83499e+07     0.00   -1.030536e+03 km/s
# 17.1 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## Cross-Validation: Finding The Most Reliable Image

# %% [markdown]
# In the previous step, `L1` and `Ltsv` are treated as fixed parameters. In practice, however, these parameters must be optimized to obtain the most reliable image for given visibility data. PRIISM implements a cross validation for optimization. In general, cross validation is time-consuming process because it requires to solve the problem many times and we need to search broad range of `L1-Ltsv` parameter space. This step is a shorthand for  cross validation. We will search only 3x3 parameter space (`L1_list` and `Ltsv_list`) and will perform 4-fold cross validation (default is 10-fold). The most reliable image will be stored in `twhya_b7cont_cv.fits` (i.e., `f'{imageprefix}.fits'`).
#
# Although this is shorthand, it may take up to 20 minutes or more depending on the machine spec. Log messages are suppresed.

# %%
# %%timeit -n 1 -r 1
import logging

# disable INFO logs
logging.disable(logging.INFO)

L1_list = [1e-1, 1e0, 1e1]
Ltsv_list = [1e2, 1e3, 1e4]
num_fold = 4

worker.crossvalidation(
    L1_list, Ltsv_list, num_fold=num_fold,
    imageprefix='twhya_b7cont_cv', imagepolicy='full',
    summarize=True, figfile='cvresult.png',
    datafile='cvresult.dat', maxiter=1000, resultasinitialimage=True, scalehyperparam=False
)

# enable INFO logs
logging.disable(logging.NOTSET)
# Out:
# 2026/08/28 07:16:38	WARNING	crossvalidation	***WARNING*** crossvalidation will be deprecated in the future. Please use optimizeparameters instead.
# 6min 45s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## Accelerating cross-validation with Bayesian optimization
#
# The `crossvalidation` method has an option to choose optimizer. Default optimizer is `'classical'` which evaluates each pair of `L1` and `Ltsv` in order to find the most reliable combination. In general, `'classical'` optimizer takes time because all combinations of given sets of `L1` and `Ltsv` must be evaluated. This makes practically difficult to seach wide range of `L1` and `Ltsv`. To address this issue, we've introduced another optimizer, `'bayesian'`. The `'bayesian'` optimizer performs Bayesian optimization to reach the most reliable combination with less number of evaluation instead of evaluating individual hyperparameter pairs. Below is an example of obtaining the best result among 12x12 hyperparameters (144 pairs) with up to 15 evaluations, i.e. almost 1/10 of total number of combinations. You will see the same (or close) result to the one obtained by the `'classical'` optimizer. You can choose, or combine, these optimizers as needed to reach the best image.
#
# Although this is shorthand, it may take up to 20 minutes or more depending on the machine spec.

# %%
# %%timeit -n 1 -r 1

import logging

# disable INFO logs
logging.disable(logging.INFO)

L1_list = [1e-1, 1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10]
Ltsv_list =  [1e-1, 1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10]
num_fold = 4

worker.crossvalidation(
    L1_list, Ltsv_list, num_fold=num_fold,
    imageprefix='twhya_b7cont_cvbayes', imagepolicy='full',
    summarize=True, figfile='cvresult2.png',
    datafile='cvresult2.dat', maxiter=1000, resultasinitialimage=False, scalehyperparam=False,
    optimizer='bayesian', bayesopt_maxiter=15
)

# enable INFO logs
logging.disable(logging.NOTSET)
# Out:
# 2026/08/28 07:23:23	WARNING	crossvalidation	***WARNING*** crossvalidation will be deprecated in the future. Please use optimizeparameters instead.
# 12min 26s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## Display Final Image

# %% [markdown]
# The created image is displayed here using the `matplotlib` module.
# Here, the final image with classical cross-validation is displayed. Only the area of 100&times;100 pixels around central region of the image is shown.

# %%
from astropy.io import fits
from matplotlib import pyplot as plt

imname = 'twhya_b7cont_cv.fits'
figname = imname.replace('fits', 'png')

pixs=256; imwd=100; exwd = (pixs-imwd) // 2
_, aa=plt.subplots(1,1, figsize=(6,6))
im=aa.imshow(fits.getdata(imname)[0,0,exwd:((pixs-1)-exwd),exwd:((pixs-1)-exwd)], 
             origin='lower', cmap='jet')
cbar=plt.colorbar(im, ax=aa)
aa.set_title(imname)
aa.set_xlabel("x [pix]",size=11)
aa.set_ylabel("y [pix]",size=11)
plt.savefig(figname, bbox_inches="tight", pad_inches=0.05)
plt.show()
